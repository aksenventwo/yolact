# %% [markdown]
# # Object Detection with SSD
# ### Here we demostrate detection on example images using SSD with PyTorch

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
import numpy as np
import cv2
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

from ssd import build_ssd
from torch.onnx.utils import _model_to_graph
from torch.onnx import OperatorExportTypes
from pytorch2sg.graph import PytorchGraph

# %% [markdown]
# ## Build SSD300 in Test Phase
# 1. Build the architecture, specifyingsize of the input image (300),
#     and number of object classes to score (21 for VOC dataset)
# 2. Next we load pretrained weights on the VOC0712 trainval dataset

# %%
net = build_ssd('test', 300, 21)    # initialize SSD
net.load_weights('../weights/ssd_300_VOC0712.pth')
#net.eval()
# Out:
# Loading weights into state dict...
# Finished!

# %%
net = torch.jit.load('../ssd.pt')
g = PytorchGraph()
trace_graph, parameter_map, _ = g.model2SSA(net,(torch.randn(1, 3, 300,300),))
trace_graph
# Out:
# graph(%input.2 : Float(1, 3, 300, 300),
#       %1 : Float(512, 512, 3, 3),
#       %2 : Float(512),
#       %3 : Float(512, 512, 3, 3),
#       %4 : Float(512),
#       %5 : Float(512, 256, 3, 3),
#       %6 : Float(512),
#       %7 : Float(256, 256, 3, 3),
#       %8 : Float(256),
#       %9 : Float(256, 256, 3, 3),
#       %10 : Float(256),
#       %11 : Float(256, 128, 3, 3),
#       %12 : Float(256),
#       %13 : Float(128, 128, 3, 3),
#       %14 : Float(128),
#       %15 : Float(128, 64, 3, 3),
#       %16 : Float(128),
#       %17 : Float(64, 64, 3, 3),
#       %18 : Float(64),
#       %19 : Float(64, 3, 3, 3),
#       %20 : Float(64),
#       %21 : Float(512),
#       %22 : Float(512, 512, 3, 3),
#       %23 : Float(512),
#       %24 : Float(512, 512, 3, 3),
#       %25 : Float(512),
#       %26 : Float(512, 512, 3, 3),
#       %27 : Float(512),
#       %28 : Float(1024, 512, 3, 3),
#       %29 : Float(1024),
#       %30 : Float(1024, 1024, 1, 1),
#       %31 : Float(1024),
#       %32 : Float(256, 1024, 1, 1),
#       %33 : Float(256),
#       %34 : Float(512, 256, 3, 3),
#       %35 : Float(512),
#       %36 : Float(128, 512, 1, 1),
#       %37 : Float(128),
#       %38 : Float(256, 128, 3, 3),
#       %39 : Float(256),
#       %40 : Float(128, 256, 1, 1),
#       %41 : Float(128),
#       %42 : Float(256, 128, 3, 3),
#       %43 : Float(256),
#       %44 : Float(128, 256, 1, 1),
#       %45 : Float(128),
#       %46 : Float(256, 128, 3, 3),
#       %47 : Float(256),
#       %48 : Float(16, 512, 3, 3),
#       %49 : Float(16),
#       %50 : Float(84, 512, 3, 3),
#       %51 : Float(84),
#       %52 : Float(24, 1024, 3, 3),
#       %53 : Float(24),
#       %54 : Float(126, 1024, 3, 3),
#       %55 : Float(126),
#       %56 : Float(24, 512, 3, 3),
#       %57 : Float(24),
#       %58 : Float(126, 512, 3, 3),
#       %59 : Float(126),
#       %60 : Float(24, 256, 3, 3),
#       %61 : Float(24),
#       %62 : Float(126, 256, 3, 3),
#       %63 : Float(126),
#       %64 : Float(16, 256, 3, 3),
#       %65 : Float(16),
#       %66 : Float(84, 256, 3, 3),
#       %67 : Float(84),
#       %68 : Float(16, 256, 3, 3),
#       %69 : Float(16),
#       %70 : Float(84, 256, 3, 3),
#       %71 : Float(84)):
#   %72 : int = prim::Constant[value=0]() # /workspace/ssd_torch/ssd.py:95:0
#   %73 : int = prim::Constant[value=1]() # /workspace/ssd_torch/ssd.py:95:0
#   %74 : int = prim::Constant[value=-1]() # /workspace/ssd_torch/ssd.py:98:0
#   %75 : int = prim::Constant[value=4]() # /workspace/ssd_torch/ssd.py:102:0
#   %76 : int = prim::Constant[value=21]() # /workspace/ssd_torch/ssd.py:103:0
#   %77 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %78 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %79 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %80 : int[] = prim::Constant[value=[1, 1]]()
#   %81 : int[] = prim::Constant[value=[1, 1]]()
#   %82 : int[] = prim::Constant[value=[1, 1]]()
#   %83 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.3 : Tensor = aten::_convolution(%input.2, %19, %20, %80, %81, %82, %78, %83, %79, %78, %78, %77) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %85 : Tensor = aten::relu_(%input0.3) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %86 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %87 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %88 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %89 : int[] = prim::Constant[value=[1, 1]]()
#   %90 : int[] = prim::Constant[value=[1, 1]]()
#   %91 : int[] = prim::Constant[value=[1, 1]]()
#   %92 : int[] = prim::Constant[value=[0, 0]]()
#   %input.3 : Tensor = aten::_convolution(%85, %17, %18, %89, %90, %91, %87, %92, %88, %87, %87, %86) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %94 : Tensor = aten::relu_(%input.3) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %95 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %96 : int[] = prim::Constant[value=[2, 2]]()
#   %97 : int[] = prim::Constant[value=[2, 2]]()
#   %98 : int[] = prim::Constant[value=[0, 0]]()
#   %99 : int[] = prim::Constant[value=[1, 1]]()
#   %input.4 : Tensor = aten::max_pool2d(%94, %96, %97, %98, %99, %95) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %101 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %102 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %103 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %104 : int[] = prim::Constant[value=[1, 1]]()
#   %105 : int[] = prim::Constant[value=[1, 1]]()
#   %106 : int[] = prim::Constant[value=[1, 1]]()
#   %107 : int[] = prim::Constant[value=[0, 0]]()
#   %input.5 : Tensor = aten::_convolution(%input.4, %15, %16, %104, %105, %106, %102, %107, %103, %102, %102, %101) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %109 : Tensor = aten::relu_(%input.5) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %110 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %111 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %112 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %113 : int[] = prim::Constant[value=[1, 1]]()
#   %114 : int[] = prim::Constant[value=[1, 1]]()
#   %115 : int[] = prim::Constant[value=[1, 1]]()
#   %116 : int[] = prim::Constant[value=[0, 0]]()
#   %input.6 : Tensor = aten::_convolution(%109, %13, %14, %113, %114, %115, %111, %116, %112, %111, %111, %110) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %118 : Tensor = aten::relu_(%input.6) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %119 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %120 : int[] = prim::Constant[value=[2, 2]]()
#   %121 : int[] = prim::Constant[value=[2, 2]]()
#   %122 : int[] = prim::Constant[value=[0, 0]]()
#   %123 : int[] = prim::Constant[value=[1, 1]]()
#   %input.7 : Tensor = aten::max_pool2d(%118, %120, %121, %122, %123, %119) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %125 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %126 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %127 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %128 : int[] = prim::Constant[value=[1, 1]]()
#   %129 : int[] = prim::Constant[value=[1, 1]]()
#   %130 : int[] = prim::Constant[value=[1, 1]]()
#   %131 : int[] = prim::Constant[value=[0, 0]]()
#   %input.8 : Tensor = aten::_convolution(%input.7, %11, %12, %128, %129, %130, %126, %131, %127, %126, %126, %125) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %133 : Tensor = aten::relu_(%input.8) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %134 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %135 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %136 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %137 : int[] = prim::Constant[value=[1, 1]]()
#   %138 : int[] = prim::Constant[value=[1, 1]]()
#   %139 : int[] = prim::Constant[value=[1, 1]]()
#   %140 : int[] = prim::Constant[value=[0, 0]]()
#   %input.9 : Tensor = aten::_convolution(%133, %9, %10, %137, %138, %139, %135, %140, %136, %135, %135, %134) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %142 : Tensor = aten::relu_(%input.9) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %143 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %144 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %145 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %146 : int[] = prim::Constant[value=[1, 1]]()
#   %147 : int[] = prim::Constant[value=[1, 1]]()
#   %148 : int[] = prim::Constant[value=[1, 1]]()
#   %149 : int[] = prim::Constant[value=[0, 0]]()
#   %input.10 : Tensor = aten::_convolution(%142, %7, %8, %146, %147, %148, %144, %149, %145, %144, %144, %143) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %151 : Tensor = aten::relu_(%input.10) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %152 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %153 : int[] = prim::Constant[value=[2, 2]]()
#   %154 : int[] = prim::Constant[value=[2, 2]]()
#   %155 : int[] = prim::Constant[value=[0, 0]]()
#   %156 : int[] = prim::Constant[value=[1, 1]]()
#   %input.11 : Tensor = aten::max_pool2d(%151, %153, %154, %155, %156, %152) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %158 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %159 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %160 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %161 : int[] = prim::Constant[value=[1, 1]]()
#   %162 : int[] = prim::Constant[value=[1, 1]]()
#   %163 : int[] = prim::Constant[value=[1, 1]]()
#   %164 : int[] = prim::Constant[value=[0, 0]]()
#   %input.12 : Tensor = aten::_convolution(%input.11, %5, %6, %161, %162, %163, %159, %164, %160, %159, %159, %158) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %166 : Tensor = aten::relu_(%input.12) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %167 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %168 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %169 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %170 : int[] = prim::Constant[value=[1, 1]]()
#   %171 : int[] = prim::Constant[value=[1, 1]]()
#   %172 : int[] = prim::Constant[value=[1, 1]]()
#   %173 : int[] = prim::Constant[value=[0, 0]]()
#   %input.13 : Tensor = aten::_convolution(%166, %3, %4, %170, %171, %172, %168, %173, %169, %168, %168, %167) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %175 : Tensor = aten::relu_(%input.13) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %176 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %177 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %178 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %179 : int[] = prim::Constant[value=[1, 1]]()
#   %180 : int[] = prim::Constant[value=[1, 1]]()
#   %181 : int[] = prim::Constant[value=[1, 1]]()
#   %182 : int[] = prim::Constant[value=[0, 0]]()
#   %input.14 : Tensor = aten::_convolution(%175, %1, %2, %179, %180, %181, %177, %182, %178, %177, %177, %176) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %184 : Tensor = aten::relu_(%input.14) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %185 : None = prim::Constant() # :0:0
#   %186 : bool = prim::Constant[value=1]() # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %187 : int = prim::Constant[value=2]() # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %188 : int = prim::Constant[value=1]() # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %189 : int = prim::Constant[value=0]() # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %190 : int = prim::Constant[value=3]() # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %191 : Tensor = aten::pow(%184, %187) # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %192 : int[] = prim::Constant[value=[1]]()
#   %193 : Tensor = aten::sum(%191, %192, %186, %185) # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %194 : Tensor = aten::sqrt(%193) # /workspace/ssd_torch/layers/modules/l2norm.py:21:0
#   %195 : float = prim::Constant[value=1e-10]()
#   %norm.1 : Tensor = aten::add(%194, %195, %188)
#   %x.1 : Tensor = aten::div(%184, %norm.1) # /workspace/ssd_torch/layers/modules/l2norm.py:23:0
#   %198 : Tensor = aten::unsqueeze(%21, %189) # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %199 : Tensor = aten::unsqueeze(%198, %187) # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %200 : Tensor = aten::unsqueeze(%199, %190) # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %201 : Tensor = aten::expand_as(%200, %x.1) # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %202 : Tensor = aten::mul(%201, %x.1) # /workspace/ssd_torch/layers/modules/l2norm.py:24:0
#   %203 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %204 : int[] = prim::Constant[value=[2, 2]]()
#   %205 : int[] = prim::Constant[value=[2, 2]]()
#   %206 : int[] = prim::Constant[value=[0, 0]]()
#   %207 : int[] = prim::Constant[value=[1, 1]]()
#   %input.15 : Tensor = aten::max_pool2d(%184, %204, %205, %206, %207, %203) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %209 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %210 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %211 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %212 : int[] = prim::Constant[value=[1, 1]]()
#   %213 : int[] = prim::Constant[value=[1, 1]]()
#   %214 : int[] = prim::Constant[value=[1, 1]]()
#   %215 : int[] = prim::Constant[value=[0, 0]]()
#   %input.16 : Tensor = aten::_convolution(%input.15, %22, %23, %212, %213, %214, %210, %215, %211, %210, %210, %209) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %217 : Tensor = aten::relu_(%input.16) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %218 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %219 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %220 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %221 : int[] = prim::Constant[value=[1, 1]]()
#   %222 : int[] = prim::Constant[value=[1, 1]]()
#   %223 : int[] = prim::Constant[value=[1, 1]]()
#   %224 : int[] = prim::Constant[value=[0, 0]]()
#   %input.17 : Tensor = aten::_convolution(%217, %24, %25, %221, %222, %223, %219, %224, %220, %219, %219, %218) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %226 : Tensor = aten::relu_(%input.17) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %227 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %228 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %229 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %230 : int[] = prim::Constant[value=[1, 1]]()
#   %231 : int[] = prim::Constant[value=[1, 1]]()
#   %232 : int[] = prim::Constant[value=[1, 1]]()
#   %233 : int[] = prim::Constant[value=[0, 0]]()
#   %input.18 : Tensor = aten::_convolution(%226, %26, %27, %230, %231, %232, %228, %233, %229, %228, %228, %227) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %235 : Tensor = aten::relu_(%input.18) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %236 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %237 : int[] = prim::Constant[value=[3, 3]]()
#   %238 : int[] = prim::Constant[value=[1, 1]]()
#   %239 : int[] = prim::Constant[value=[1, 1]]()
#   %240 : int[] = prim::Constant[value=[1, 1]]()
#   %input.19 : Tensor = aten::max_pool2d(%235, %237, %238, %239, %240, %236) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:488:0
#   %242 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %243 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %244 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %245 : int[] = prim::Constant[value=[1, 1]]()
#   %246 : int[] = prim::Constant[value=[6, 6]]()
#   %247 : int[] = prim::Constant[value=[6, 6]]()
#   %248 : int[] = prim::Constant[value=[0, 0]]()
#   %input.20 : Tensor = aten::_convolution(%input.19, %28, %29, %245, %246, %247, %243, %248, %244, %243, %243, %242) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %250 : Tensor = aten::relu_(%input.20) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %251 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %252 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %253 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %254 : int[] = prim::Constant[value=[1, 1]]()
#   %255 : int[] = prim::Constant[value=[0, 0]]()
#   %256 : int[] = prim::Constant[value=[1, 1]]()
#   %257 : int[] = prim::Constant[value=[0, 0]]()
#   %input.21 : Tensor = aten::_convolution(%250, %30, %31, %254, %255, %256, %252, %257, %253, %252, %252, %251) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %259 : Tensor = aten::relu_(%input.21) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %260 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %261 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %262 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %263 : int[] = prim::Constant[value=[1, 1]]()
#   %264 : int[] = prim::Constant[value=[0, 0]]()
#   %265 : int[] = prim::Constant[value=[1, 1]]()
#   %266 : int[] = prim::Constant[value=[0, 0]]()
#   %input.1 : Tensor = aten::_convolution(%259, %32, %33, %263, %264, %265, %261, %266, %262, %261, %261, %260) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input0.2 : Tensor = aten::relu_(%input.1) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %269 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %270 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %271 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %272 : int[] = prim::Constant[value=[2, 2]]()
#   %273 : int[] = prim::Constant[value=[1, 1]]()
#   %274 : int[] = prim::Constant[value=[1, 1]]()
#   %275 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.4 : Tensor = aten::_convolution(%input0.2, %34, %35, %272, %273, %274, %270, %275, %271, %270, %270, %269) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input1.1 : Tensor = aten::relu_(%input0.4) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %278 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %279 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %280 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %281 : int[] = prim::Constant[value=[1, 1]]()
#   %282 : int[] = prim::Constant[value=[0, 0]]()
#   %283 : int[] = prim::Constant[value=[1, 1]]()
#   %284 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.5 : Tensor = aten::_convolution(%input1.1, %36, %37, %281, %282, %283, %279, %284, %280, %279, %279, %278) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input2.1 : Tensor = aten::relu_(%input0.5) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %287 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %288 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %289 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %290 : int[] = prim::Constant[value=[2, 2]]()
#   %291 : int[] = prim::Constant[value=[1, 1]]()
#   %292 : int[] = prim::Constant[value=[1, 1]]()
#   %293 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.6 : Tensor = aten::_convolution(%input2.1, %38, %39, %290, %291, %292, %288, %293, %289, %288, %288, %287) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input3.1 : Tensor = aten::relu_(%input0.6) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %296 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %297 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %298 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %299 : int[] = prim::Constant[value=[1, 1]]()
#   %300 : int[] = prim::Constant[value=[0, 0]]()
#   %301 : int[] = prim::Constant[value=[1, 1]]()
#   %302 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.7 : Tensor = aten::_convolution(%input3.1, %40, %41, %299, %300, %301, %297, %302, %298, %297, %297, %296) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input4.1 : Tensor = aten::relu_(%input0.7) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %305 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %306 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %307 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %308 : int[] = prim::Constant[value=[1, 1]]()
#   %309 : int[] = prim::Constant[value=[0, 0]]()
#   %310 : int[] = prim::Constant[value=[1, 1]]()
#   %311 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.8 : Tensor = aten::_convolution(%input4.1, %42, %43, %308, %309, %310, %306, %311, %307, %306, %306, %305) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input5.1 : Tensor = aten::relu_(%input0.8) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %314 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %315 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %316 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %317 : int[] = prim::Constant[value=[1, 1]]()
#   %318 : int[] = prim::Constant[value=[0, 0]]()
#   %319 : int[] = prim::Constant[value=[1, 1]]()
#   %320 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.9 : Tensor = aten::_convolution(%input5.1, %44, %45, %317, %318, %319, %315, %320, %316, %315, %315, %314) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input6.1 : Tensor = aten::relu_(%input0.9) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %323 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %324 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %325 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %326 : int[] = prim::Constant[value=[1, 1]]()
#   %327 : int[] = prim::Constant[value=[0, 0]]()
#   %328 : int[] = prim::Constant[value=[1, 1]]()
#   %329 : int[] = prim::Constant[value=[0, 0]]()
#   %input0.1 : Tensor = aten::_convolution(%input6.1, %46, %47, %326, %327, %328, %324, %329, %325, %324, %324, %323) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %input7.1 : Tensor = aten::relu_(%input0.1) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:912:0
#   %332 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %333 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %334 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %335 : int[] = prim::Constant[value=[1, 1]]()
#   %336 : int[] = prim::Constant[value=[1, 1]]()
#   %337 : int[] = prim::Constant[value=[1, 1]]()
#   %338 : int[] = prim::Constant[value=[0, 0]]()
#   %339 : Tensor = aten::_convolution(%202, %48, %49, %335, %336, %337, %333, %338, %334, %333, %333, %332) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %340 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %341 : Tensor = aten::permute(%339, %340) # /workspace/ssd_torch/ssd.py:95:0
#   %o.1 : Tensor = aten::contiguous(%341, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %343 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %344 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %345 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %346 : int[] = prim::Constant[value=[1, 1]]()
#   %347 : int[] = prim::Constant[value=[1, 1]]()
#   %348 : int[] = prim::Constant[value=[1, 1]]()
#   %349 : int[] = prim::Constant[value=[0, 0]]()
#   %350 : Tensor = aten::_convolution(%202, %50, %51, %346, %347, %348, %344, %349, %345, %344, %344, %343) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %351 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %352 : Tensor = aten::permute(%350, %351) # /workspace/ssd_torch/ssd.py:96:0
#   %o0.1 : Tensor = aten::contiguous(%352, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %354 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %355 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %356 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %357 : int[] = prim::Constant[value=[1, 1]]()
#   %358 : int[] = prim::Constant[value=[1, 1]]()
#   %359 : int[] = prim::Constant[value=[1, 1]]()
#   %360 : int[] = prim::Constant[value=[0, 0]]()
#   %361 : Tensor = aten::_convolution(%259, %52, %53, %357, %358, %359, %355, %360, %356, %355, %355, %354) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %362 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %363 : Tensor = aten::permute(%361, %362) # /workspace/ssd_torch/ssd.py:95:0
#   %o1.1 : Tensor = aten::contiguous(%363, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %365 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %366 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %367 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %368 : int[] = prim::Constant[value=[1, 1]]()
#   %369 : int[] = prim::Constant[value=[1, 1]]()
#   %370 : int[] = prim::Constant[value=[1, 1]]()
#   %371 : int[] = prim::Constant[value=[0, 0]]()
#   %372 : Tensor = aten::_convolution(%259, %54, %55, %368, %369, %370, %366, %371, %367, %366, %366, %365) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %373 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %374 : Tensor = aten::permute(%372, %373) # /workspace/ssd_torch/ssd.py:96:0
#   %o2.1 : Tensor = aten::contiguous(%374, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %376 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %377 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %378 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %379 : int[] = prim::Constant[value=[1, 1]]()
#   %380 : int[] = prim::Constant[value=[1, 1]]()
#   %381 : int[] = prim::Constant[value=[1, 1]]()
#   %382 : int[] = prim::Constant[value=[0, 0]]()
#   %383 : Tensor = aten::_convolution(%input1.1, %56, %57, %379, %380, %381, %377, %382, %378, %377, %377, %376) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %384 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %385 : Tensor = aten::permute(%383, %384) # /workspace/ssd_torch/ssd.py:95:0
#   %o3.1 : Tensor = aten::contiguous(%385, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %387 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %388 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %389 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %390 : int[] = prim::Constant[value=[1, 1]]()
#   %391 : int[] = prim::Constant[value=[1, 1]]()
#   %392 : int[] = prim::Constant[value=[1, 1]]()
#   %393 : int[] = prim::Constant[value=[0, 0]]()
#   %394 : Tensor = aten::_convolution(%input1.1, %58, %59, %390, %391, %392, %388, %393, %389, %388, %388, %387) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %395 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %396 : Tensor = aten::permute(%394, %395) # /workspace/ssd_torch/ssd.py:96:0
#   %o4.1 : Tensor = aten::contiguous(%396, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %398 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %399 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %400 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %401 : int[] = prim::Constant[value=[1, 1]]()
#   %402 : int[] = prim::Constant[value=[1, 1]]()
#   %403 : int[] = prim::Constant[value=[1, 1]]()
#   %404 : int[] = prim::Constant[value=[0, 0]]()
#   %405 : Tensor = aten::_convolution(%input3.1, %60, %61, %401, %402, %403, %399, %404, %400, %399, %399, %398) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %406 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %407 : Tensor = aten::permute(%405, %406) # /workspace/ssd_torch/ssd.py:95:0
#   %o5.1 : Tensor = aten::contiguous(%407, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %409 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %410 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %411 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %412 : int[] = prim::Constant[value=[1, 1]]()
#   %413 : int[] = prim::Constant[value=[1, 1]]()
#   %414 : int[] = prim::Constant[value=[1, 1]]()
#   %415 : int[] = prim::Constant[value=[0, 0]]()
#   %416 : Tensor = aten::_convolution(%input3.1, %62, %63, %412, %413, %414, %410, %415, %411, %410, %410, %409) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %417 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %418 : Tensor = aten::permute(%416, %417) # /workspace/ssd_torch/ssd.py:96:0
#   %o6.1 : Tensor = aten::contiguous(%418, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %420 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %421 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %422 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %423 : int[] = prim::Constant[value=[1, 1]]()
#   %424 : int[] = prim::Constant[value=[1, 1]]()
#   %425 : int[] = prim::Constant[value=[1, 1]]()
#   %426 : int[] = prim::Constant[value=[0, 0]]()
#   %427 : Tensor = aten::_convolution(%input5.1, %64, %65, %423, %424, %425, %421, %426, %422, %421, %421, %420) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %428 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %429 : Tensor = aten::permute(%427, %428) # /workspace/ssd_torch/ssd.py:95:0
#   %o7.1 : Tensor = aten::contiguous(%429, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %431 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %432 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %433 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %434 : int[] = prim::Constant[value=[1, 1]]()
#   %435 : int[] = prim::Constant[value=[1, 1]]()
#   %436 : int[] = prim::Constant[value=[1, 1]]()
#   %437 : int[] = prim::Constant[value=[0, 0]]()
#   %438 : Tensor = aten::_convolution(%input5.1, %66, %67, %434, %435, %436, %432, %437, %433, %432, %432, %431) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %439 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %440 : Tensor = aten::permute(%438, %439) # /workspace/ssd_torch/ssd.py:96:0
#   %o8.1 : Tensor = aten::contiguous(%440, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %442 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %443 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %444 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %445 : int[] = prim::Constant[value=[1, 1]]()
#   %446 : int[] = prim::Constant[value=[1, 1]]()
#   %447 : int[] = prim::Constant[value=[1, 1]]()
#   %448 : int[] = prim::Constant[value=[0, 0]]()
#   %449 : Tensor = aten::_convolution(%input7.1, %68, %69, %445, %446, %447, %443, %448, %444, %443, %443, %442) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %450 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %451 : Tensor = aten::permute(%449, %450) # /workspace/ssd_torch/ssd.py:95:0
#   %o9.1 : Tensor = aten::contiguous(%451, %72) # /workspace/ssd_torch/ssd.py:95:0
#   %453 : bool = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %454 : bool = prim::Constant[value=0]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %455 : int = prim::Constant[value=1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %456 : int[] = prim::Constant[value=[1, 1]]()
#   %457 : int[] = prim::Constant[value=[1, 1]]()
#   %458 : int[] = prim::Constant[value=[1, 1]]()
#   %459 : int[] = prim::Constant[value=[0, 0]]()
#   %460 : Tensor = aten::_convolution(%input7.1, %70, %71, %456, %457, %458, %454, %459, %455, %454, %454, %453) # /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py:342:0
#   %461 : int[] = prim::Constant[value=[0, 2, 3, 1]]()
#   %462 : Tensor = aten::permute(%460, %461) # /workspace/ssd_torch/ssd.py:96:0
#   %o10.1 : Tensor = aten::contiguous(%462, %72) # /workspace/ssd_torch/ssd.py:96:0
#   %464 : int = aten::size(%o.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %465 : int = aten::size(%o1.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %466 : int = aten::size(%o3.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %467 : int = aten::size(%o5.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %468 : int = aten::size(%o7.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %469 : int = aten::size(%o9.1, %72) # /workspace/ssd_torch/ssd.py:98:0
#   %470 : int[] = prim::ListConstruct(%464, %74)
#   %471 : Tensor = aten::view(%o.1, %470) # /workspace/ssd_torch/ssd.py:98:0
#   %472 : int[] = prim::ListConstruct(%465, %74)
#   %473 : Tensor = aten::view(%o1.1, %472) # /workspace/ssd_torch/ssd.py:98:0
#   %474 : int[] = prim::ListConstruct(%466, %74)
#   %475 : Tensor = aten::view(%o3.1, %474) # /workspace/ssd_torch/ssd.py:98:0
#   %476 : int[] = prim::ListConstruct(%467, %74)
#   %477 : Tensor = aten::view(%o5.1, %476) # /workspace/ssd_torch/ssd.py:98:0
#   %478 : int[] = prim::ListConstruct(%468, %74)
#   %479 : Tensor = aten::view(%o7.1, %478) # /workspace/ssd_torch/ssd.py:98:0
#   %480 : int[] = prim::ListConstruct(%469, %74)
#   %481 : Tensor = aten::view(%o9.1, %480) # /workspace/ssd_torch/ssd.py:98:0
#   %482 : Tensor[] = prim::ListConstruct(%471, %473, %475, %477, %479, %481)
#   %loc.1 : Tensor = aten::cat(%482, %73) # /workspace/ssd_torch/ssd.py:98:0
#   %484 : int = aten::size(%o0.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %485 : int = aten::size(%o2.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %486 : int = aten::size(%o4.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %487 : int = aten::size(%o6.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %488 : int = aten::size(%o8.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %489 : int = aten::size(%o10.1, %72) # /workspace/ssd_torch/ssd.py:99:0
#   %490 : int[] = prim::ListConstruct(%484, %74)
#   %491 : Tensor = aten::view(%o0.1, %490) # /workspace/ssd_torch/ssd.py:99:0
#   %492 : int[] = prim::ListConstruct(%485, %74)
#   %493 : Tensor = aten::view(%o2.1, %492) # /workspace/ssd_torch/ssd.py:99:0
#   %494 : int[] = prim::ListConstruct(%486, %74)
#   %495 : Tensor = aten::view(%o4.1, %494) # /workspace/ssd_torch/ssd.py:99:0
#   %496 : int[] = prim::ListConstruct(%487, %74)
#   %497 : Tensor = aten::view(%o6.1, %496) # /workspace/ssd_torch/ssd.py:99:0
#   %498 : int[] = prim::ListConstruct(%488, %74)
#   %499 : Tensor = aten::view(%o8.1, %498) # /workspace/ssd_torch/ssd.py:99:0
#   %500 : int[] = prim::ListConstruct(%489, %74)
#   %501 : Tensor = aten::view(%o10.1, %500) # /workspace/ssd_torch/ssd.py:99:0
#   %502 : Tensor[] = prim::ListConstruct(%491, %493, %495, %497, %499, %501)
#   %conf.1 : Tensor = aten::cat(%502, %73) # /workspace/ssd_torch/ssd.py:99:0
#   %504 : int = aten::size(%loc.1, %72) # /workspace/ssd_torch/ssd.py:102:0
#   %505 : int[] = prim::ListConstruct(%504, %74, %75)
#   %loc_data.1 : Tensor = aten::view(%loc.1, %505) # /workspace/ssd_torch/ssd.py:102:0
#   %507 : int = aten::size(%conf.1, %72) # /workspace/ssd_torch/ssd.py:103:0
#   %508 : int[] = prim::ListConstruct(%507, %74, %76)
#   %input8.1 : Tensor = aten::view(%conf.1, %508) # /workspace/ssd_torch/ssd.py:103:0
#   %510 : None = prim::Constant() # :0:0
#   %511 : int = prim::Constant[value=-1]() # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1231:0
#   %512 : Tensor = aten::softmax(%input8.1, %511, %510) # /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1231:0
#   %513 : None = prim::Constant() # :0:0
#   %514 : bool = prim::Constant[value=0]() # :0:0
#   %515 : int = prim::Constant[value=0]() # /workspace/ssd_torch/layers/functions/detection.py:11:33
#   %516 : int = prim::Constant[value=1]() # /workspace/ssd_torch/layers/functions/detection.py:18:35
#   %517 : int = prim::Constant[value=9223372036854775807]() # :0:0
#   %518 : float = prim::Constant[value=0.01]() # /workspace/ssd_torch/layers/functions/detection.py:33:34
#   %519 : int = prim::Constant[value=6]() # /workspace/ssd_torch/layers/functions/detection.py:36:28
#   %520 : int = prim::Constant[value=200]() # /workspace/ssd_torch/layers/functions/detection.py:51:21
#   %521 : int[] = prim::Constant[value=[8732, 21]]()
#   %scores.1 : Tensor = aten::view(%512, %521) # /workspace/ssd_torch/layers/functions/detection.py:13:13
#   %523 : Tensor = aten::select(%loc_data.1, %515, %515) # /workspace/ssd_torch/layers/functions/detection.py:15:19
#   %524 : int = prim::Constant[value=0]() # /workspace/ssd_torch/layers/box_utils.py:152:8
#   %525 : int = prim::Constant[value=9223372036854775807]() # :0:0
#   %526 : int = prim::Constant[value=1]() # /workspace/ssd_torch/layers/box_utils.py:152:8
#   %527 : int = prim::Constant[value=2]() # /workspace/ssd_torch/layers/box_utils.py:152:19
#   %528 : float = prim::Constant[value=0.1]() # /workspace/ssd_torch/layers/box_utils.py:152:53
#   %529 : float = prim::Constant[value=0.2]() # /workspace/ssd_torch/layers/box_utils.py:153:47
#   %530 : Tensor = aten::slice(%523, %524, %524, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:152:24
#   %531 : Tensor = aten::slice(%530, %526, %524, %527, %526) # /workspace/ssd_torch/layers/box_utils.py:152:24
#   %532 : Float(8732, 2) = prim::Constant[value=<Tensor>]()
#   %533 : Float(8732, 2) = prim::Constant[value=<Tensor>]()
#   %534 : Tensor = aten::mul(%531, %532) # /workspace/ssd_torch/layers/box_utils.py:152:24
#   %535 : Tensor = aten::mul(%534, %528) # /workspace/ssd_torch/layers/box_utils.py:152:24
#   %536 : Tensor = aten::slice(%523, %524, %524, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:153:34
#   %537 : Tensor = aten::slice(%536, %526, %527, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:153:34
#   %538 : Float(8732, 2) = prim::Constant[value=<Tensor>]()
#   %539 : Tensor = aten::mul(%537, %529) # /workspace/ssd_torch/layers/box_utils.py:153:34
#   %540 : Tensor = aten::exp(%539) # /workspace/ssd_torch/layers/box_utils.py:153:24
#   %541 : Tensor = aten::add(%533, %535, %526) # /workspace/ssd_torch/layers/box_utils.py:152:8
#   %542 : Tensor = aten::mul(%538, %540) # /workspace/ssd_torch/layers/box_utils.py:153:8
#   %543 : Tensor[] = prim::ListConstruct(%541, %542)
#   %boxes.1 : Tensor = aten::cat(%543, %526) # /workspace/ssd_torch/layers/box_utils.py:151:12
#   %545 : Tensor = aten::slice(%boxes.1, %524, %524, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:156:13
#   %546 : Tensor = aten::slice(%boxes.1, %524, %524, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:156:29
#   %547 : Tensor = aten::slice(%546, %526, %527, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:156:29
#   %548 : Tensor = aten::slice(%545, %526, %524, %527, %526) # /workspace/ssd_torch/layers/box_utils.py:156:13
#   %549 : Tensor = aten::div(%547, %527) # /workspace/ssd_torch/layers/box_utils.py:156:29
#   %xboxes.1 : Tensor = aten::sub(%548, %549, %526) # /workspace/ssd_torch/layers/box_utils.py:156:13
#   %551 : Tensor = aten::slice(%boxes.1, %524, %524, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:157:13
#   %552 : Tensor = aten::slice(%551, %526, %527, %525, %526) # /workspace/ssd_torch/layers/box_utils.py:157:13
#   %yboxes.1 : Tensor = aten::add(%552, %xboxes.1, %526) # /workspace/ssd_torch/layers/box_utils.py:157:13
#   %554 : Tensor[] = prim::ListConstruct(%xboxes.1, %yboxes.1)
#   %boxes.2 : Tensor = aten::cat(%554, %526) # /workspace/ssd_torch/layers/box_utils.py:158:12
#   %556 : int[] = prim::Constant[value=[8732, 1, 4]]()
#   %557 : Tensor = aten::view(%boxes.2, %556) # /workspace/ssd_torch/layers/functions/detection.py:18:12
#   %558 : int[] = prim::Constant[value=[8732, 21, 4]]()
#   %boxes0.1 : Tensor = aten::expand(%557, %558, %514) # /workspace/ssd_torch/layers/functions/detection.py:18:12
#   %560 : Long(1, 21) = prim::Constant[value=<Tensor>]()
#   %labels0.1 : Tensor = aten::expand_as(%560, %scores.1) # /workspace/ssd_torch/layers/functions/detection.py:20:13
#   %562 : Tensor = aten::slice(%boxes0.1, %515, %515, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:23:12
#   %boxes1.1 : Tensor = aten::slice(%562, %516, %516, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:23:12
#   %564 : Tensor = aten::slice(%scores.1, %515, %515, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:24:13
#   %scores0.1 : Tensor = aten::slice(%564, %516, %516, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:24:13
#   %566 : Tensor = aten::slice(%labels0.1, %515, %515, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:25:13
#   %labels1.1 : Tensor = aten::slice(%566, %516, %516, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:25:13
#   %568 : int[] = prim::Constant[value=[-1, 4]]()
#   %boxes2.1 : Tensor = aten::reshape(%boxes1.1, %568) # /workspace/ssd_torch/layers/functions/detection.py:28:12
#   %570 : int[] = prim::Constant[value=[-1]]()
#   %scores1.1 : Tensor = aten::reshape(%scores0.1, %570) # /workspace/ssd_torch/layers/functions/detection.py:29:13
#   %572 : int[] = prim::Constant[value=[-1]]()
#   %labels2.1 : Tensor = aten::reshape(%labels1.1, %572) # /workspace/ssd_torch/layers/functions/detection.py:30:13
#   %574 : Tensor = aten::gt(%scores1.1, %518) # /workspace/ssd_torch/layers/functions/detection.py:33:25
#   %575 : Tensor = aten::nonzero(%574) # /workspace/ssd_torch/layers/functions/detection.py:33:11
#   %inds.1 : Tensor = aten::squeeze(%575, %516) # /workspace/ssd_torch/layers/functions/detection.py:33:11
#   %577 : Tensor?[] = prim::ListConstruct(%inds.1)
#   %boxes3.1 : Tensor = aten::index(%boxes2.1, %577) # /workspace/ssd_torch/layers/functions/detection.py:34:28
#   %579 : Tensor?[] = prim::ListConstruct(%inds.1)
#   %scores2.1 : Tensor = aten::index(%scores1.1, %579) # /workspace/ssd_torch/layers/functions/detection.py:34:41
#   %581 : Tensor?[] = prim::ListConstruct(%inds.1)
#   %labels3.1 : Tensor = aten::index(%labels2.1, %581) # /workspace/ssd_torch/layers/functions/detection.py:34:55
#   %583 : Float(1, 6) = prim::Constant[value= 0  0  0  0  0  0 [ CPUFloatType{1,6} ]]()
#   %584 : int = aten::numel(%boxes3.1) # /workspace/ssd_torch/layers/functions/detection.py:37:7
#   %585 : bool = aten::eq(%584, %515) # /workspace/ssd_torch/layers/functions/detection.py:37:7
#   %586 : Tensor = prim::If(%585) # /workspace/ssd_torch/layers/functions/detection.py:37:4
#     block0():
#       -> (%583)
#     block1():
#       %max_coordinate.1 : Tensor = aten::max(%boxes3.1) # /workspace/ssd_torch/layers/functions/detection.py:44:25
#       %588 : Tensor = aten::to(%labels3.1, %boxes3.1, %514, %514, %513) # /workspace/ssd_torch/layers/functions/detection.py:45:18
#       %589 : Tensor = aten::add(%max_coordinate.1, %516, %516) # /workspace/ssd_torch/layers/functions/detection.py:45:38
#       %offsets.1 : Tensor = aten::mul(%588, %589) # /workspace/ssd_torch/layers/functions/detection.py:45:18
#       %591 : Tensor = aten::slice(%offsets.1, %515, %515, %517, %516) # /workspace/ssd_torch/layers/functions/detection.py:46:32
#       %592 : Tensor = aten::unsqueeze(%591, %516) # /workspace/ssd_torch/layers/functions/detection.py:46:32
#       %boxes_for_nms.1 : Tensor = aten::add(%boxes3.1, %592, %516) # /workspace/ssd_torch/layers/functions/detection.py:46:24
#       %594 : Double() = prim::Constant[value={0.45}]()
#       %595 : bool = prim::Constant[value=1]() # :0:0
#       %596 : None = prim::Constant() # :0:0
#       %597 : int = prim::Constant[value=1]() # /workspace/ssd_torch/layers/box_utils.py:185:24
#       %598 : int = prim::Constant[value=0]() # /workspace/ssd_torch/layers/box_utils.py:186:18
#       %599 : int = prim::Constant[value=9223372036854775807]() # /workspace/ssd_torch/layers/box_utils.py:193:4
#       %600 : int = prim::Constant[value=2]() # /workspace/ssd_torch/layers/box_utils.py:188:18
#       %601 : int = prim::Constant[value=3]() # /workspace/ssd_torch/layers/box_utils.py:189:18
#       %602 : float = prim::Constant[value=0]() # /workspace/ssd_torch/layers/box_utils.py:213:31
#       %603 : Long(1, 1) = prim::Constant[value={0}]()
#       %604 : Tensor = aten::slice(%boxes_for_nms.1, %598, %598, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:186:9
#       %x1.1 : Tensor = aten::select(%604, %597, %598) # /workspace/ssd_torch/layers/box_utils.py:186:9
#       %606 : Tensor = aten::slice(%boxes_for_nms.1, %598, %598, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:187:9
#       %y1.1 : Tensor = aten::select(%606, %597, %597) # /workspace/ssd_torch/layers/box_utils.py:187:9
#       %608 : Tensor = aten::slice(%boxes_for_nms.1, %598, %598, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:188:9
#       %x2.1 : Tensor = aten::select(%608, %597, %600) # /workspace/ssd_torch/layers/box_utils.py:188:9
#       %610 : Tensor = aten::slice(%boxes_for_nms.1, %598, %598, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:189:9
#       %y2.1 : Tensor = aten::select(%610, %597, %601) # /workspace/ssd_torch/layers/box_utils.py:189:9
#       %612 : Tensor = aten::sub(%x2.1, %x1.1, %597) # /workspace/ssd_torch/layers/box_utils.py:190:21
#       %613 : Tensor = aten::sub(%y2.1, %y1.1, %597) # /workspace/ssd_torch/layers/box_utils.py:190:30
#       %area.1 : Tensor = aten::mul(%612, %613) # /workspace/ssd_torch/layers/box_utils.py:190:11
#       %615 : int = aten::size(%scores2.1, %598) # /workspace/ssd_torch/layers/box_utils.py:191:32
#       %v : Tensor, %idx.1 : Tensor = aten::topk(%scores2.1, %615, %598, %595, %595) # /workspace/ssd_torch/layers/box_utils.py:191:13
#       %618 : int = aten::numel(%idx.1) # /workspace/ssd_torch/layers/box_utils.py:193:10
#       %619 : bool = aten::gt(%618, %597) # /workspace/ssd_torch/layers/box_utils.py:193:10
#       %keep0 : Tensor, %idx0 : Tensor = prim::Loop(%599, %619, %603, %idx.1) # /workspace/ssd_torch/layers/box_utils.py:193:4
#         block0(%622 : int, %keep0.4 : Tensor, %idx0.4 : Tensor):
#           %i.1 : Tensor = aten::select(%idx0.4, %598, %598) # /workspace/ssd_torch/layers/box_utils.py:195:12
#           %626 : Long(1, 1) = prim::Constant[value={1}]()
#           %627 : Tensor = aten::mul(%626, %i.1) # /workspace/ssd_torch/layers/box_utils.py:197:32
#           %628 : Tensor[] = prim::ListConstruct(%keep0.4, %627)
#           %keep1.1 : Tensor = aten::cat(%628, %597) # /workspace/ssd_torch/layers/box_utils.py:197:15
#           %idx1.1 : Tensor = aten::slice(%idx0.4, %598, %597, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:199:14
#           %xx1.1 : Tensor = aten::index_select(%x1.1, %598, %idx1.1) # /workspace/ssd_torch/layers/box_utils.py:201:14
#           %yy1.1 : Tensor = aten::index_select(%y1.1, %598, %idx1.1) # /workspace/ssd_torch/layers/box_utils.py:202:14
#           %xx2.1 : Tensor = aten::index_select(%x2.1, %598, %idx1.1) # /workspace/ssd_torch/layers/box_utils.py:203:14
#           %yy2.1 : Tensor = aten::index_select(%y2.1, %598, %idx1.1) # /workspace/ssd_torch/layers/box_utils.py:204:14
#           %635 : Tensor?[] = prim::ListConstruct(%i.1)
#           %636 : Tensor = aten::index(%x1.1, %635) # /workspace/ssd_torch/layers/box_utils.py:206:41
#           %637 : float = aten::Float(%636) # /workspace/ssd_torch/layers/box_utils.py:206:35
#           %xx10.1 : Tensor = aten::clamp(%xx1.1, %637, %596) # /workspace/ssd_torch/layers/box_utils.py:206:14
#           %639 : Tensor?[] = prim::ListConstruct(%i.1)
#           %640 : Tensor = aten::index(%y1.1, %639) # /workspace/ssd_torch/layers/box_utils.py:207:41
#           %641 : float = aten::Float(%640) # /workspace/ssd_torch/layers/box_utils.py:207:35
#           %yy10.1 : Tensor = aten::clamp(%yy1.1, %641, %596) # /workspace/ssd_torch/layers/box_utils.py:207:14
#           %643 : Tensor?[] = prim::ListConstruct(%i.1)
#           %644 : Tensor = aten::index(%x2.1, %643) # /workspace/ssd_torch/layers/box_utils.py:208:41
#           %645 : float = aten::Float(%644) # /workspace/ssd_torch/layers/box_utils.py:208:35
#           %xx20.1 : Tensor = aten::clamp(%xx2.1, %596, %645) # /workspace/ssd_torch/layers/box_utils.py:208:14
#           %647 : Tensor?[] = prim::ListConstruct(%i.1)
#           %648 : Tensor = aten::index(%y2.1, %647) # /workspace/ssd_torch/layers/box_utils.py:209:41
#           %649 : float = aten::Float(%648) # /workspace/ssd_torch/layers/box_utils.py:209:35
#           %yy20.1 : Tensor = aten::clamp(%yy2.1, %596, %649) # /workspace/ssd_torch/layers/box_utils.py:209:14
#           %w.1 : Tensor = aten::sub(%xx20.1, %xx10.1, %597) # /workspace/ssd_torch/layers/box_utils.py:210:12
#           %h.1 : Tensor = aten::sub(%yy20.1, %yy10.1, %597) # /workspace/ssd_torch/layers/box_utils.py:211:12
#           %w0.1 : Tensor = aten::clamp(%w.1, %602, %596) # /workspace/ssd_torch/layers/box_utils.py:213:12
#           %h0.1 : Tensor = aten::clamp(%h.1, %602, %596) # /workspace/ssd_torch/layers/box_utils.py:214:12
#           %inter.1 : Tensor = aten::mul(%w0.1, %h0.1) # /workspace/ssd_torch/layers/box_utils.py:215:16
#           %rem_areas.1 : Tensor = aten::index_select(%area.1, %598, %idx1.1) # /workspace/ssd_torch/layers/box_utils.py:217:20
#           %657 : Tensor?[] = prim::ListConstruct(%i.1)
#           %658 : Tensor = aten::index(%area.1, %657) # /workspace/ssd_torch/layers/box_utils.py:218:28
#           %659 : Tensor = aten::add(%rem_areas.1, %658, %597) # /workspace/ssd_torch/layers/box_utils.py:218:16
#           %union.1 : Tensor = aten::sub(%659, %inter.1, %597) # /workspace/ssd_torch/layers/box_utils.py:218:16
#           %iou.1 : Tensor = aten::div(%inter.1, %union.1) # /workspace/ssd_torch/layers/box_utils.py:219:14
#           %662 : Tensor = aten::le(%iou.1, %594) # /workspace/ssd_torch/layers/box_utils.py:221:18
#           %663 : Tensor?[] = prim::ListConstruct(%662)
#           %idx2.1 : Tensor = aten::index(%idx1.1, %663) # /workspace/ssd_torch/layers/box_utils.py:221:14
#           %665 : int = aten::numel(%idx2.1) # /workspace/ssd_torch/layers/box_utils.py:193:10
#           %666 : bool = aten::gt(%665, %597) # /workspace/ssd_torch/layers/box_utils.py:193:10
#           -> (%666, %keep1.1, %idx2.1)
#       %667 : Tensor = aten::squeeze(%keep0) # /workspace/ssd_torch/layers/box_utils.py:223:11
#       %keep.2 : Tensor = aten::slice(%667, %598, %597, %599, %597) # /workspace/ssd_torch/layers/box_utils.py:223:11
#       %keep0.1 : Tensor = aten::slice(%keep.2, %515, %515, %520, %516) # /workspace/ssd_torch/layers/functions/detection.py:51:15
#       %670 : Tensor?[] = prim::ListConstruct(%keep0.1)
#       %boxes4.1 : Tensor = aten::index(%boxes3.1, %670) # /workspace/ssd_torch/layers/functions/detection.py:52:32
#       %672 : Tensor?[] = prim::ListConstruct(%keep0.1)
#       %scores3.1 : Tensor = aten::index(%scores2.1, %672) # /workspace/ssd_torch/layers/functions/detection.py:52:45
#       %674 : Tensor?[] = prim::ListConstruct(%keep0.1)
#       %labels4.1 : Tensor = aten::index(%labels3.1, %674) # /workspace/ssd_torch/layers/functions/detection.py:52:59
#       %labels5.1 : Tensor = aten::to(%labels4.1, %519, %514, %514, %513) # /workspace/ssd_torch/layers/functions/detection.py:53:17
#       %labels6.1 : Tensor = aten::unsqueeze(%labels5.1, %516) # /workspace/ssd_torch/layers/functions/detection.py:54:17
#       %scores4.1 : Tensor = aten::unsqueeze(%scores3.1, %516) # /workspace/ssd_torch/layers/functions/detection.py:55:17
#       %679 : Tensor[] = prim::ListConstruct(%labels6.1, %scores4.1, %boxes4.1)
#       %680 : Tensor = aten::cat(%679, %516) # /workspace/ssd_torch/layers/functions/detection.py:56:17
#       -> (%680)
#   return (%586)

# %% [markdown]
# ## Load Image
# ### Here we just load a sample image from the VOC07 dataset

# %%
image = cv2.imread('../data/example.jpg', cv2.IMREAD_COLOR)  # uncomment if dataset not downloaded
#image = cv2.imread('../data/VOCdevkit/VOC2007/JPEGImages/000025.jpg', cv2.IMREAD_COLOR)
# %matplotlib inline
from matplotlib import pyplot as plt
#from data import VOCDetection, VOC_ROOT, VOCAnnotationTransform
# here we specify year (07 or 12) and dataset ('test', 'val', 'train') 
#testset = VOCDetection('../data/VOCdevkit', [('2007', 'val')], None, VOCAnnotationTransform())
#img_id = 60
#image = testset.pull_image(img_id)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# View the sampled input image before transform
plt.figure(figsize=(10,10))
plt.imshow(rgb_image)
plt.show()

# %% [markdown]
# ## Pre-process the input.
# #### Using the torchvision package, we can create a Compose of multiple built-in transorm ops to apply
# For SSD, at test time we use a custom BaseTransform callable to
# resize our image to 300x300, subtract the dataset's mean rgb values,
# and swap the color channels for input to SSD300.

# %%
x = cv2.resize(image, (300, 300)).astype(np.float32)
x -= (104.0, 117.0, 123.0)
x = x.astype(np.float32)
x = x[:, :, ::-1].copy()
plt.imshow(x)
x = torch.from_numpy(x).permute(2, 0, 1)
x = x.unsqueeze(0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
y = net(x)
print(y.shape)
# Out:
# torch.Size([169, 6])

# %%
xx = x.numpy().astype(np.float32)

# %%
import pyRbRuntime as rt

net_r = rt.Network('../ssd.sg', dp=[rt.CPU])
outputs = net_r.Run(xx)

# %%
from layers import *

loc = torch.tensor(outputs['500'])
conf = torch.tensor(outputs['501'])
softmax = nn.Softmax(dim=-1)
detect = Detect(21, 0, 200, 0.01, 0.45)
output = detect(
    loc.view(loc.size(0), -1, 4), 
    softmax(conf.view(conf.size(0), -1, 21)),
    net.priors.type(torch.float32))

# %%
y = outputs['586']
y.shape[0]
y = torch.tensor(y)

# %% [markdown]
# ## SSD Forward Pass
# ### Now just wrap the image in a Variable so it is recognized by PyTorch autograd

# %% [markdown]
# ## Parse the Detections and View Results
# Filter outputs with confidence scores lower than a threshold
# Here we choose 60%

# %%
from data import VOC_CLASSES as labels

plt.figure(figsize=(10,10))
colors = plt.cm.hsv(np.linspace(0, 1, 21)).tolist()
plt.imshow(rgb_image)  # plot the image for matplotlib
currentAxis = plt.gca()

detections = y.data
# scale each detection back up to the image
scale = torch.Tensor(rgb_image.shape[1::-1]).repeat(2)
for i in range(detections.size(0)):
    if detections[i, 1] > 0.5:
        label_name = labels[int(detections[i, 0])-1]
        score = detections[i, 1]
        display_txt = '%s: %.2f'%(label_name, score)
        pt = (detections[i,2:]*scale).cpu().numpy()
        coords = (pt[0], pt[1]), pt[2]-pt[0]+1, pt[3]-pt[1]+1
        color = colors[i]
        currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=2))
        currentAxis.text(pt[0], pt[1], display_txt, bbox={'facecolor':color, 'alpha':0.5})
# Out:
# ((332.04395, -19.059631), 159.94912719726562, 393.71502685546875)
# ((195.38817, -15.740477), 157.32496643066406, 340.75384521484375)
# ((50.783978, 144.95006), 340.5638122558594, 229.10215759277344)
